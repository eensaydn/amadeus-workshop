# %% [markdown]
# ## Basit Soru-Cevap Sistemi (Basic Q&A)
#
# ## 🎯 Bu Kodun Amacı
# LLM'lerle ilk etkileşimimizi kurmak ve temel API kullanımını öğrenmek.
#
# ## Ne Yapacağız?
# - **Groq API** bağlantısı kuracağız
# - **.env dosyasından** API anahtarını güvenli şekilde yükleyeceğiz
# - **LLaMA 3.3 70B** modelini kullanacağız
# - Kullanıcıdan **3 soru** alacağız
# - Her soruya model **kısa ve net yanıtlar** verecek
# - Temel **prompt engineering** (sistem ve kullanıcı mesajları) öğreneceğiz
#
# ## Çalıştırma
# Kodu çalıştırdığınızda 3 kez soru sormanız istenecek ve AI her soruya yanıt verecek.

# %%
import os
from dotenv import load_dotenv
from groq import Groq

load_dotenv()
client = Groq(api_key=os.getenv("GROQ_API_KEY"))

def ask_question(question):
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[
            {"role": "system", "content": "You are a helpful assistant. Answer questions briefly and clearly."},
            {"role": "user", "content": question}
        ],
        temperature=0.3,
        max_tokens=200
    )
    return response.choices[0].message.content

# Ask 3 questions
for i in range(1, 4):
    print(f"\nQUESTION {i}/3")
    user_question = input("Your question: ")
    answer = ask_question(user_question)
    print(f"\nAnswer: {answer}\n")

print("✅ All questions answered!")
# Out:
# QUESTION 1/3
#
# Answer: Hello. How can I help you today?
#
#
# QUESTION 2/3
#
# Answer: I'm an artificial intelligence, so I don't have a physical location or origin. I exist to assist users like you from anywhere in the world.
#
#
# QUESTION 3/3
#
# Answer: I don't have a personal owner. I'm a computer program designed to assist and provide information to users, and I'm managed by a team of developers and researchers.
#
# ✅ All questions answered!
